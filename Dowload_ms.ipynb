# %%
import json
import requests
from PIL import Image
import os

# %%
iiif_url = 'https://www.e-codices.unifr.ch/metadata/iiif/csg-0267/manifest.json'
output_folder = os.getcwd()

# %%
def get_manifest(iiif_url) -> tuple:

    """
    Retrieves the IIIF manifest from a given URL and extracts relevant metadata.

    Args:
        iiif_url (str): The URL of the IIIF manifest.

    Returns:
        tuple: A tuple containing:
            - manifest (dict): The JSON data of the IIIF manifest.
            - iiif_version (int): The IIIF version extracted from the manifest context.
            - library_domain (str): The domain of the library hosting the manifest.

    Raises:
        Exception: If an error occurs while fetching or processing the manifest.
    """

    # Send an HTTP GET request to fetch the IIIF manifest
    response = requests.get(iiif_url)

    # Check if the manifest was successfully loaded 
    try:
        if response.status_code == 200:
            # Parse the JSON response
            manifest = response.json()
            print(f"Manifest {iiif_url} loaded with success.")

            # Extract the IIIF version from the '@context' field
            iiif_version = manifest['@context'].split('/')[-2]

            # Extract the library domain from the URL
            library_domain = iiif_url.split('/')[2]
            
            # Return the extracted data
            return manifest, int(iiif_version), library_domain
            
        else:
            print(f"Error loading the manifest: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while loading the manifest: {e}")
        raise  # Re-raise the exception for upstream handling
# Out:
# Manifest https://www.e-codices.unifr.ch/metadata/iiif/csg-0267/manifest.json loaded with success.
# 2 www.e-codices.unifr.ch
# IIIF version : 2

# %%
def images_data_iiif_3(manifest:str, library_domain:str) -> tuple:
    """
    Extracts image information from an IIIF v3 manifest.

    Args:
        manifest (dict): The JSON data of the IIIF manifest.
        library_domain (str): The domain of the library hosting the manifest.

    Returns:
        tuple: A tuple containing:
            - ms_name (str): The manuscript's name extracted from the manifest.
            - images_info (list of dict): A list containing image metadata such as:
                - canvasNum (int): The index of the canvas.
                - imageLabel (str): The label of the image.
                - urlImage (str): The download URL of the image.
                - imageFormat (str): The format of the image (e.g., jpg, png).
                - imageWidthAsDeclared (int): The declared width of the image.
                - imageHeightAsDeclared (int): The declared height of the image.

    Raises:
        Exception: If an error occurs during processing, an error message is printed, 
                  and an empty list is returned.
    """
    try:
        # Extract the manuscript name from the manifest
        ms_name = manifest['label']['en'][0]

        # Extract the canvases from the manifest
        canvases = manifest['items']

        # Create a list to store image metadata
        images_info = []

        # Loop through the canvases to extract image information
        for idx, canvas in enumerate(canvases):
            # Extract the image label if available, otherwise assign a default value
            image_label = canvas['label']['en'][0] if 'label' in canvas and 'en' in canvas['label'] else "Unknow label"
            
            # Retrieve declared image dimensions
            image_width_declared = canvas.get('width', 0)
            image_height_declared = canvas.get('height', 0)

            # Extract the image URL from the manifest
            image_url = canvas['items'][0]['items'][0]['body']['id']

            if library_domain == 'digi.vatlib.it':
                # Special case for 'digi.vatlib.it' domain
                download_url = image_url + '/full/max/0/default.jpg'
            else:
                # Modify the URL to ensure the maximum available size
                download_url = image_url.replace(
                    image_url.split('/')[-3], 'max') # Use ‘max’ to be sure of retrieving the largest authorised size and avoid restrictions due to the maximum threshold (max_pixels).
            
            # Extract the image format from the URL
            image_format = download_url.split('.')[-1]
        
            # Append the extracted image information to the list
            images_info.append({
                'canvasNum': idx,
                'imageLabel': image_label,
                'urlImage': download_url,
                'imageFormat' : image_format,
                'imageWidthAsDeclared': image_width_declared,
                'imageHeightAsDeclared': image_height_declared
            })

        print(f"Found {len(images_info)} images in the manifest.")
        
        return ms_name, images_info
    
    except Exception as e:
        print(f"An error occured : {e}")
        return None, []

images_data_iiif_3(iiif_url)
# Out:
# Trouvé 98 images dans le manifeste.
# ('add ms 11283',
#  [{'canvasNum': 0,
#    'imageLabel': 'front',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000001/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5526,
#    'imageHeightAsDeclared': 7940},
#   {'canvasNum': 1,
#    'imageLabel': 'front-i',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000002/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5411,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 2,
#    'imageLabel': 'fs.ir',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000003/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5385,
#    'imageHeightAsDeclared': 8105},
#   {'canvasNum': 3,
#    'imageLabel': 'fs.iv',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000004/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5545,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 4,
#    'imageLabel': 'fs.iiar',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000005/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5261,
#    'imageHeightAsDeclared': 8071},
#   {'canvasNum': 5,
#    'imageLabel': 'fs.iibr',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000006/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5242,
#    'imageHeightAsDeclared': 8049},
#   {'canvasNum': 6,
#    'imageLabel': 'fs.iibv',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000007/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5482,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 7,
#    'imageLabel': 'fs.iiir',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000008/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5160,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 8,
#    'imageLabel': 'fs.iiiv',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000009/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5445,
#    'imageHeightAsDeclared': 8104},
#   {'canvasNum': 9,
#    'imageLabel': 'f.1r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00000a/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5160,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 10,
#    'imageLabel': 'f.1v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00000b/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5518,
#    'imageHeightAsDeclared': 8117},
#   {'canvasNum': 11,
#    'imageLabel': 'f.2r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00000c/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5230,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 12,
#    'imageLabel': 'f.2v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00000d/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5505,
#    'imageHeightAsDeclared': 8088},
#   {'canvasNum': 13,
#    'imageLabel': 'f.3r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00000e/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5242,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 14,
#    'imageLabel': 'f.3v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00000f/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5486,
#    'imageHeightAsDeclared': 8096},
#   {'canvasNum': 15,
#    'imageLabel': 'f.4r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000010/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5236,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 16,
#    'imageLabel': 'f.4v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000011/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5523,
#    'imageHeightAsDeclared': 8126},
#   {'canvasNum': 17,
#    'imageLabel': 'f.5r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000012/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5255,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 18,
#    'imageLabel': 'f.5v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000013/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5411,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 19,
#    'imageLabel': 'f.6r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000014/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5235,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 20,
#    'imageLabel': 'f.6v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000015/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5411,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 21,
#    'imageLabel': 'f.7r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000016/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5160,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 22,
#    'imageLabel': 'f.7v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000017/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5411,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 23,
#    'imageLabel': 'f.8r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000018/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5160,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 24,
#    'imageLabel': 'f.8v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000019/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5482,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 25,
#    'imageLabel': 'f.9r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00001a/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5160,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 26,
#    'imageLabel': 'f.9v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00001b/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5411,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 27,
#    'imageLabel': 'f.10r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00001c/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5160,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 28,
#    'imageLabel': 'f.10v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00001d/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 29,
#    'imageLabel': 'f.11r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00001e/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5290,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 30,
#    'imageLabel': 'f.11v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00001f/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 31,
#    'imageLabel': 'f.12r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000020/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5346,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 32,
#    'imageLabel': 'f.12v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000021/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 33,
#    'imageLabel': 'f.13r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000022/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5160,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 34,
#    'imageLabel': 'f.13v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000023/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 35,
#    'imageLabel': 'f.14r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000024/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5160,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 36,
#    'imageLabel': 'f.14v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000025/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 37,
#    'imageLabel': 'f.15r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000026/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5262,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 38,
#    'imageLabel': 'f.15v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000027/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 39,
#    'imageLabel': 'f.16r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000028/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5160,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 40,
#    'imageLabel': 'f.16v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000029/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 41,
#    'imageLabel': 'f.17r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00002a/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5160,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 42,
#    'imageLabel': 'f.17v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00002b/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 43,
#    'imageLabel': 'f.18r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00002c/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5359,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 44,
#    'imageLabel': 'f.18v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00002d/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 45,
#    'imageLabel': 'f.19r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00002e/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5308,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 46,
#    'imageLabel': 'f.19v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00002f/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 47,
#    'imageLabel': 'f.20r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000030/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5331,
#    'imageHeightAsDeclared': 8009},
#   {'canvasNum': 48,
#    'imageLabel': 'f.20v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000031/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 49,
#    'imageLabel': 'f.21r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000032/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8152},
#   {'canvasNum': 50,
#    'imageLabel': 'f.21v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000033/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5479,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 51,
#    'imageLabel': 'f.22r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000034/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8142},
#   {'canvasNum': 52,
#    'imageLabel': 'f.22v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000035/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5519,
#    'imageHeightAsDeclared': 8015},
#   {'canvasNum': 53,
#    'imageLabel': 'f.23r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000036/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8115},
#   {'canvasNum': 54,
#    'imageLabel': 'f.23v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000037/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5423,
#    'imageHeightAsDeclared': 8077},
#   {'canvasNum': 55,
#    'imageLabel': 'f.24r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000038/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 56,
#    'imageLabel': 'f.24v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000039/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5517,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 57,
#    'imageLabel': 'f.25r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00003a/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8162},
#   {'canvasNum': 58,
#    'imageLabel': 'f.25v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00003b/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5439,
#    'imageHeightAsDeclared': 8056},
#   {'canvasNum': 59,
#    'imageLabel': 'f.26r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00003c/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 60,
#    'imageLabel': 'f.26v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00003d/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5404,
#    'imageHeightAsDeclared': 8058},
#   {'canvasNum': 61,
#    'imageLabel': 'f.27r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00003e/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 62,
#    'imageLabel': 'f.27v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00003f/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5380,
#    'imageHeightAsDeclared': 8040},
#   {'canvasNum': 63,
#    'imageLabel': 'f.28r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000040/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 64,
#    'imageLabel': 'f.28v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000041/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5344,
#    'imageHeightAsDeclared': 8045},
#   {'canvasNum': 65,
#    'imageLabel': 'f.29r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000042/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 66,
#    'imageLabel': 'f.29v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000043/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 67,
#    'imageLabel': 'f.30r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000044/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 68,
#    'imageLabel': 'f.30v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000045/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 69,
#    'imageLabel': 'f.31r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000046/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 70,
#    'imageLabel': 'f.31v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000047/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 71,
#    'imageLabel': 'f.32r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000048/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 72,
#    'imageLabel': 'f.32v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000049/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 73,
#    'imageLabel': 'f.33r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00004a/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 74,
#    'imageLabel': 'f.33v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00004b/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 75,
#    'imageLabel': 'f.34r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00004c/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 76,
#    'imageLabel': 'f.34v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00004d/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 77,
#    'imageLabel': 'f.35r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00004e/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 78,
#    'imageLabel': 'f.35v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00004f/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5253,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 79,
#    'imageLabel': 'f.36r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000050/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 80,
#    'imageLabel': 'f.36v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000051/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 81,
#    'imageLabel': 'f.37r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000052/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 82,
#    'imageLabel': 'f.37v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000053/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 83,
#    'imageLabel': 'f.38r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000054/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 84,
#    'imageLabel': 'f.38v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000055/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 85,
#    'imageLabel': 'f.39r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000056/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 86,
#    'imageLabel': 'f.39v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000057/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 87,
#    'imageLabel': 'f.40r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000058/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5504,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 88,
#    'imageLabel': 'f.40v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000059/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 89,
#    'imageLabel': 'f.41r',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00005a/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 90,
#    'imageLabel': 'f.41v',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00005b/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5294,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 91,
#    'imageLabel': 'fse.ivr',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00005c/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 92,
#    'imageLabel': 'fse.ivv',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00005d/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5261,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 93,
#    'imageLabel': 'fse.vr',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00005e/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 94,
#    'imageLabel': 'fse.vv',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x00005f/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 95,
#    'imageLabel': 'back-i',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000060/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5534,
#    'imageHeightAsDeclared': 8024},
#   {'canvasNum': 96,
#    'imageLabel': 'back',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000061/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 5526,
#    'imageHeightAsDeclared': 7940},
#   {'canvasNum': 97,
#    'imageLabel': 'spine',
#    'urlImage': 'https://bl.digirati.io/images/ark:/81055/vdc_100055965343.0x000062/full/max/0/default.jpg',
#    'imageFormat': 'jpg',
#    'imageWidthAsDeclared': 2197,
#    'imageHeightAsDeclared': 8577}])

# %%
def images_data_iiif_2(manifest, library_domain):
    """
    Extracts image information from an IIIF v2 manifest.

    Args:
        manifest (dict): The JSON data of the IIIF manifest.
        library_domain (str): The domain of the library hosting the manifest.

    Returns:
        list of dict: A list containing image metadata, where each dictionary includes:
            - canvasNum (int): The index of the canvas.
            - imageLabel (str): The label of the image.
            - urlImage (str): The URL of the image.
            - imageFormat (str): The format of the image (e.g., jpg, png).
            - imageWidthAsDeclared (int): The declared width of the image.
            - imageHeightAsDeclared (int): The declared height of the image.

    Raises:
        Exception: If an error occurs during processing, an error message is printed, 
                  and an empty list is returned.
    """
    try:
        # Extract canvases from the manifest
        canvases = manifest['sequences'][0]['canvases']

        # Create a list to store image metadata
        images_info = []

        # Loop through the canvases to extract image information
        for idx, canvas in enumerate(canvases):
            canvas_num = idx # Canvas index in the manifest
            image_label = canvas['label'] # Extract image label

            # Extract image resource details
            image_resource = canvas['images'][0]['resource']
            image_url = image_resource['@id']
            image_format = image_url.split('.')[-1] # Extract image format from URL
            image_width_declared = image_resource.get('width', 0)
            image_height_declared = image_resource.get('height', 0)
            
            # Special handling for 'digi.vatlib.it' domain
            if library_domain == 'digi.vatlib.it':
                image_url = canvas['images'][0]['resource']['@id'] + '/full/full/0/default.jpg'

            # Append the extracted image information to the list    
            images_info.append({
                'canvasNum': canvas_num,
                'imageLabel': image_label,
                'urlImage': image_url,
                'imageFormat' : image_format,
                'imageWidthAsDeclared': image_width_declared,
                'imageHeightAsDeclared': image_height_declared
            })

        print(f"Found {len(images_info)} images in the manifest.")
        
        return images_info

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
def download_from_iiif(iiif_url, output_folder):

    # Créer un dossier pour stocker les images téléchargées
    
    folder_name, images_info = images_data_iiif_3(iiif_url)
    folder_path = os.path.join(output_folder, folder_name)
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)

    # Parcourir la liste des images et les télécharger
    for idx, image in enumerate(images_info):
        url = image['urlImage']
        image_filename = f"image_{idx+1}.jpg"
        image_path = os.path.join(folder_path, image_filename)
        
        try:
            response = requests.get(url)
            html_code = response.status_code
            print(f"Téléchargement de {image_filename} - Code HTTP : {html_code}")
            
            if response.status_code == 200:
                # Enregistrer l'image sur le disque
                with open(image_path, 'wb') as file:
                    file.write(response.content)
                image['imageFileName'] = image_filename
                image['folderPath'] = folder_path
                image['htmlCode'] = html_code
            else:
                print(f"Erreur lors du téléchargement de l'image : {html_code}")
                image['htmlCode'] = html_code
        except Exception as e:
            print(f"Exception lors du téléchargement de l'image : {e}")
            image['htmlCode'] = 'Exception'

# %%
manifest, iiif_version, library_domain = get_manifest(iiif_url)
print(iiif_version, library_domain)

# %%
download_from_iiif(iiif_url, output_folder)
# Out:
# Trouvé 98 images dans le manifeste.
# Téléchargement de image_1.jpg - Code HTTP : 200
# Téléchargement de image_2.jpg - Code HTTP : 200
# Téléchargement de image_3.jpg - Code HTTP : 200
# Téléchargement de image_4.jpg - Code HTTP : 200
# Téléchargement de image_5.jpg - Code HTTP : 200
# Téléchargement de image_6.jpg - Code HTTP : 200
# Téléchargement de image_7.jpg - Code HTTP : 200
# Téléchargement de image_8.jpg - Code HTTP : 200
# Téléchargement de image_9.jpg - Code HTTP : 200
# Téléchargement de image_10.jpg - Code HTTP : 200
# Téléchargement de image_11.jpg - Code HTTP : 200
# Téléchargement de image_12.jpg - Code HTTP : 200
# Téléchargement de image_13.jpg - Code HTTP : 200
# Téléchargement de image_14.jpg - Code HTTP : 200
# Téléchargement de image_15.jpg - Code HTTP : 200
# Téléchargement de image_16.jpg - Code HTTP : 200
# Téléchargement de image_17.jpg - Code HTTP : 200
# Téléchargement de image_18.jpg - Code HTTP : 200
# Téléchargement de image_19.jpg - Code HTTP : 200
# Téléchargement de image_20.jpg - Code HTTP : 200
# Téléchargement de image_21.jpg - Code HTTP : 200
# Téléchargement de image_22.jpg - Code HTTP : 200
# Téléchargement de image_23.jpg - Code HTTP : 200
# Téléchargement de image_24.jpg - Code HTTP : 200
# Téléchargement de image_25.jpg - Code HTTP : 200
# Téléchargement de image_26.jpg - Code HTTP : 200
# Téléchargement de image_27.jpg - Code HTTP : 200
# Téléchargement de image_28.jpg - Code HTTP : 200
# Téléchargement de image_29.jpg - Code HTTP : 200
# Téléchargement de image_30.jpg - Code HTTP : 200
# Téléchargement de image_31.jpg - Code HTTP : 200
# Téléchargement de image_32.jpg - Code HTTP : 200
# Téléchargement de image_33.jpg - Code HTTP : 200
# Téléchargement de image_34.jpg - Code HTTP : 200
# Téléchargement de image_35.jpg - Code HTTP : 200
# Téléchargement de image_36.jpg - Code HTTP : 200
# Téléchargement de image_37.jpg - Code HTTP : 200
# Téléchargement de image_38.jpg - Code HTTP : 200
# Téléchargement de image_39.jpg - Code HTTP : 200
# Téléchargement de image_40.jpg - Code HTTP : 200
# Téléchargement de image_41.jpg - Code HTTP : 200
# Téléchargement de image_42.jpg - Code HTTP : 200
# Téléchargement de image_43.jpg - Code HTTP : 200
# Téléchargement de image_44.jpg - Code HTTP : 200
# Téléchargement de image_45.jpg - Code HTTP : 200
# Téléchargement de image_46.jpg - Code HTTP : 200
# Téléchargement de image_47.jpg - Code HTTP : 200
# Téléchargement de image_48.jpg - Code HTTP : 200
# Téléchargement de image_49.jpg - Code HTTP : 200
# Téléchargement de image_50.jpg - Code HTTP : 200
# Téléchargement de image_51.jpg - Code HTTP : 200
# Téléchargement de image_52.jpg - Code HTTP : 200
# Téléchargement de image_53.jpg - Code HTTP : 200
# Téléchargement de image_54.jpg - Code HTTP : 200
# Téléchargement de image_55.jpg - Code HTTP : 200
# Téléchargement de image_56.jpg - Code HTTP : 200
# Téléchargement de image_57.jpg - Code HTTP : 200
# Téléchargement de image_58.jpg - Code HTTP : 200
# Téléchargement de image_59.jpg - Code HTTP : 200
# Téléchargement de image_60.jpg - Code HTTP : 200
# Téléchargement de image_61.jpg - Code HTTP : 200
# Téléchargement de image_62.jpg - Code HTTP : 200
# Téléchargement de image_63.jpg - Code HTTP : 200
# Téléchargement de image_64.jpg - Code HTTP : 200
# Téléchargement de image_65.jpg - Code HTTP : 200
# Téléchargement de image_66.jpg - Code HTTP : 200
# Téléchargement de image_67.jpg - Code HTTP : 200
# Téléchargement de image_68.jpg - Code HTTP : 200
# Téléchargement de image_69.jpg - Code HTTP : 200
# Téléchargement de image_70.jpg - Code HTTP : 200
# Téléchargement de image_71.jpg - Code HTTP : 200
# Téléchargement de image_72.jpg - Code HTTP : 200
# Téléchargement de image_73.jpg - Code HTTP : 200
# Téléchargement de image_74.jpg - Code HTTP : 200
# Téléchargement de image_75.jpg - Code HTTP : 200
# Téléchargement de image_76.jpg - Code HTTP : 200
# Téléchargement de image_77.jpg - Code HTTP : 200
# Téléchargement de image_78.jpg - Code HTTP : 200
# Téléchargement de image_79.jpg - Code HTTP : 200
# Téléchargement de image_80.jpg - Code HTTP : 200
# Téléchargement de image_81.jpg - Code HTTP : 200
# Téléchargement de image_82.jpg - Code HTTP : 200
# Téléchargement de image_83.jpg - Code HTTP : 200
# Téléchargement de image_84.jpg - Code HTTP : 200
# Téléchargement de image_85.jpg - Code HTTP : 200
# Téléchargement de image_86.jpg - Code HTTP : 200
# Téléchargement de image_87.jpg - Code HTTP : 200
# Téléchargement de image_88.jpg - Code HTTP : 200
# Téléchargement de image_89.jpg - Code HTTP : 200
# Téléchargement de image_90.jpg - Code HTTP : 200
# Téléchargement de image_91.jpg - Code HTTP : 200
# Téléchargement de image_92.jpg - Code HTTP : 200
# Téléchargement de image_93.jpg - Code HTTP : 200
# Téléchargement de image_94.jpg - Code HTTP : 200
# Téléchargement de image_95.jpg - Code HTTP : 200
# Téléchargement de image_96.jpg - Code HTTP : 200
# Téléchargement de image_97.jpg - Code HTTP : 200
# Téléchargement de image_98.jpg - Code HTTP : 200

# %%
# Parcourir les images pour récupérer les caractéristiques et les enregistrer
for image in images_info:
    image_filename = image.get('imageFileName')
    
    # Vérifier si l'image est valide (nom de fichier et code HTML = 200)
    if image_filename and image.get('htmlCode') == 200:
        image_path = os.path.join(image['folderPath'], image_filename)
        txt_filename = os.path.splitext(image_filename)[0] + '.txt'
        txt_path = os.path.join(image['folderPath'], txt_filename)
        
        # Ouvrir l'image avec PIL et récupérer les dimensions téléchargées (size retourne un tuple (width, height) )
        with Image.open(image_path) as img:
            image_width_downloaded, image_height_downloaded = img.size
            image['imageWidthAsDownloaded'] = image_width_downloaded
            image['imageHeightAsDownloaded'] = image_height_downloaded
        
        # Liste des clés à écrire dans le fichier .txt
        data_to_write = [
            'imageFileName', 'canvasId', 'urlImage', 'folderPath', 'imageLabel',
            'imageWidthAsDeclared', 'imageHeightAsDeclared', 'htmlCode',
            'imageWidthAsDownloaded', 'imageHeightAsDownloaded'
        ]
        
        # Enregistrer les caractéristiques dans le fichier .txt
        with open(txt_path, 'w', encoding='utf-8') as txt_file:
            for key in data_to_write:
                value = image.get(key)
                # Si la valeur est nulle (None ou chaîne vide), remplacer par "Non défini"
                if not value:
                    value = 'Non défini'
                txt_file.write(f"{key}: {value}\n")
        
        print(f"Caractéristiques enregistrées dans {txt_filename}")
    else:
        print(f"Image non téléchargée ou erreur lors du téléchargement pour {image.get('imageLabel', 'Inconnu')}")

# %%
url = 'https://digi.vatlib.it/iiifimage/MSS_Ross.982/Ross.982_0016_fa_0002v.jp2'
download_url = url + '/full/full/0/default.jpg'

download_url
# Out:
# 'https://digi.vatlib.it/iiifimage/MSS_Ross.982/Ross.982_0016_fa_0002v.jp2/full/full/0/default.jpg'

# %%
import random
def lancer_de(nombre,faces):
    tirage = []
    for i in range(nombre):
        tirage.append(random.randint(1,faces))
        
    return tirage

# %%
mon_tirage = lancer_de(3,6)
print(type(mon_tirage))
# Out:
# <class 'list'>
